# %%
import pandas as pd
import numpy as np
import pymysql
import time
import datetime
import joblib
import re
import difflib
import copy
import requests
import json
import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_rows', 300)
pd.options.display.min_rows = None
pd.set_option('display.max_columns', 100)

# %%
data=joblib.load('TEST.pkl')
data2=joblib.load('TEST2.pkl')
data=data.append(data2)

# %%
# 字段
col=["phone_count_name_duplicates_drop",
"phone_count_t_p_drop",
"phone_count_t_drop",
"phone_count_valid_drop",
 "phone_count_company_phone_p_drop",
"7install_to_create_days_nmbers_mean",
"7install_to_create_daysothers",
"180install_to_create_days_nmbers_std",
"7install_to_create_daysreview_app_otherscnt",
"180install_to_create_days_days_mean",
"21install_to_create_days_nmbers_mean",
"7install_to_create_days_nmbers_max",
"7install_to_create_days_nmbers_std",
"7install_to_create_days_days_count",
"7install_to_create_daystotal_cnt",
"7install_to_create_dayspackageName_finance_cnt",
"21install_to_create_daysreview_middle1_appcnt",
"21install_to_create_daysapp_level1cnt",
"21install_to_create_daysapp_level2cnt",
"21install_to_create_daysapp_level3cnt",
"21install_to_create_daysapp_level4cnt",
"21update_to_create_daysreview_middle1_appcnt",
"21install_to_create_daysapp_level2cnt",
"21install_to_create_daysFinance",
"21install_to_create_daysinstall_middle_appcnt",
"21update_to_create_daysinstall_middle_appcnt",
"21install_to_create_daysreview_unpopular_second_appcnt",
"21update_to_create_daysapp_level3cnt",
"21update_to_create_daysreview_unpopular_second_appcnt",
"21install_to_create_daysGame",
"21install_to_create_daysOffice",
"21update_to_create_daysinstall_unpopular_second_appcnt",
"21install_to_create_daysothers",
"21install_to_create_daysEntertainment",
"21install_to_create_daysLifestyle",
"21install_to_create_daysCommunications",
"21install_to_create_daysShopping",
"21install_to_create_daysreview_middle2_appcnt",
"21install_to_create_daysreview_app_otherscnt",
"21install_to_create_daysreview_popular_appcnt",
"21install_to_create_daysreview_unpopular_appcnt"]

# %%
col=['loan_id']+list(set(col))

# %%
joblib.dump(col,'app_connect_feat.pkl')
# Out:
# ['app_connect_feat.pkl']

# %%
data.iloc[-1:]=-9999

# %%
wrong_data=data[col].iloc[-1:]

# %%
wrong_data.index=[0]

# %%
joblib.dump(wrong_data,'wrong_data.pkl')
# Out:
# ['wrong_data.pkl']

# %%
21install_to_create_daysreview_middle1_appcnt
# Out:
#   File "<ipython-input-109-aaa086215aa5>", line 1
#     21install_to_create_daysreview_middle1_appcnt
#                                                 ^
# SyntaxError: invalid syntax

# %%
180update_to_create_daysShopping

# %%
toad.quality(data,target='repay_order_status')[0:50]
# Out:
#                                                         iv      gini  \
# phone_count_t_drop                                0.084927  0.462345
# phone_count_name_drop                             0.084927  0.462345
# phone_count_t_p_drop                              0.083085  0.463640
# phone_count_valid_t                               0.078822  0.463504
# phone_count_valid_drop                            0.077782  0.462825
# phone_count_valid_p_drop                          0.076943  0.463646
# 7install_to_create_days_nmbers_mean               0.076139  0.462752
# 7install_to_create_daysothers                     0.075228  0.464621
# phone_count_t                                     0.073530  0.463443
# 180install_to_create_days_nmbers_std              0.069644  0.465303
# 7install_to_create_daysreview_app_otherscnt       0.067209  0.463293
# 21install_to_create_days_nmbers_std               0.065429  0.463170
# 180install_to_create_days_days_mean               0.064764  0.465456
# ...

# %%
21install_to_create_daysOffice

# %%
21install_to_create_daysinstall_middle_appcnt

# %%
toad.KS_bucket(data['phone_count_company_phone_p_drop'],1-data['repay_order_status'],bucket=50)
# Out:
#     min  max  bads  goods  total  bad_rate  good_rate      odds  bad_prop  \
# 0     0    0   874   1421   2295  0.380828   0.619172  0.615060  0.396912
# 1     1    1   125    180    305  0.409836   0.590164  0.694444  0.056767
# 2     2    2   146    226    372  0.392473   0.607527  0.646018  0.066303
# 3     3    4    64    150    214  0.299065   0.700935  0.426667  0.029064
# 4     5    5    26     29     55  0.472727   0.527273  0.896552  0.011807
# 5     6    6    28     49     77  0.363636   0.636364  0.571429  0.012716
# 6     7    7   147    189    336  0.437500   0.562500  0.777778  0.066757
# 7     8    8   171    348    519  0.329480   0.670520  0.491379  0.077657
# 8     9    9   101    218    319  0.316614   0.683386  0.463303  0.045867
# 9    10   13    91    146    237  0.383966   0.616034  0.623288  0.041326
# 10   14  142    41     67    108  0.379630   0.620370  0.611940  0.018619
# 11  143  165    46     84    130  0.353846   0.646154  0.547619  0.020890
# ...

# %%
data['21install_to_create_daysreview_middle1_appcnt']
# Out:
# 0       0
# 1       1
# 2       0
# 3       1
# 4       1
# 5       4
# 6       1
# 7       2
# 8       0
# 9       0
# 10      1
# 11      0
# 12      2
# 13      1
# 14      1
# 15      3
# 16      1
# 17      1
# 18      1
# 19      0
# 20      3
# 21      1
# 22      2
# 23      0
# 24      0
# 25      1
# 26      1
# 27      1
# 28      0
# 29      1
# 30      0
# 31      2
# 32      1
# 33      2
# 34      1
# 35      0
# 36      3
# 37      2
# 38      2
# 39      0
# 40      1
# 41      0
# 42      5
# 43      0
# 44      0
# 45      0
# 46      0
# 47      1
# 48      1
# 49      1
# 50      1
# 51      0
# 52      0
# 53      9
# 54      1
# 55      0
# 56      0
# 57      2
# 58      0
# 59      5
# 60      1
# 61      0
# 62      2
# 63      3
# 64      0
# 65      0
# 66      1
# 67      1
# 68      0
# 69      0
# 70      2
# 71      1
# 72      0
# 73      1
# 74      5
# 75      2
# 76      1
# 77      1
# 78      0
# 79      4
# 80      0
# 81      0
# 82      0
# ...

# %%
data['21install_to_create_daysreview_middle2_appcnt']

# %%
data['21install_to_create_daysreview_app_otherscnt']

# %%
data['21install_to_create_daysreview_popular_appcnt']

# %%
data['21install_to_create_daysreview_unpopular_appcnt']

# %%
data['21install_to_create_daysreview_unpopular_second_appcnt']
